# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %% [markdown]
# Column types
# * Numerical - PassengerID ,  Fare  ,Age
# * Categorical - Survived ,Pclass , Sex , SibSp , Embarked , Parch
# * Mixed -  Name , ticket ,Cabin

# %% [markdown]
# Steps in EDA
# * first understand type of data - Int , Categorical ,Mixed
# * Univariate analysis
# * Bivariate  analysis
# * Multi and feature engineering
# * Outlier detection

# %% [markdown]
# ### Univariate Analysis
# * Distribution Analysis: To identify shape , central tendency and dispersion.
#     * Shape:
#         * Normal(symetrical)data is in middle ,where mean ,median and mode are same.
#         * Skewed: Not symmetric , one tail is longer than the other.
#         * Bimodal: Distribution with two peaks.
#      * Central tendency:
#           * Mean .median and mode.
#     * Dispersion:  Its a statistical term used to descibe  the spread of data.
#          * range: diff btwn largest and smallest value in data set.
#          * Variance: Distance from the mean.
#          * Deviation : Sqrt of  variance.
#
# * Identifying potential issues : Outliers ,skewness and missing values.

# %% [markdown]
# At first in univariater analysis we work on Integer.
# * descriptive statistics : We calc the mean ,median ,mode ,var,deviation and quartile.
# * visualization : histograms ,boxplots, density plots,kdeplots.
# * Identifying outliers : identifying using visualization, multiple reasons for outliers..
#    like data entry errroe , legit errors etc .
# * Skewness : We solve it using roboust statistical methods.

# %% [markdown]
# The goal is to find if a passenger will survive or not.
# * Numerical - PassengerID ,  Fare  ,Age
# Here PassengerID makes no sense for predicting passenger survival.So we'll ignore it.

# %% [markdown]
# #### Age

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# 25% are below 20  q1(boxplot)
# 50% are below 28  (median)
# 75% are below 38

# %%
ax = sns.histplot(data = df['Age'],
                  bins = 20);
# or 
''' 
Using pandas
df['Age'].plot(kind = 'hist', bins = 20)
'''
# Out:
# " \nUsing pandas\ndf['Age'].plot(kind = 'hist', bins = 20)\n"

# %%
df['Age'].plot(kind = 'kde');

# %% [markdown]
# Calculating skewness by using skew function ,is its away from 0 ,close to 1 then its
# positively skewed data.If its perefectly 0 then it means its normally distributed.

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
ax = sns.boxplot(data = df['Age']);
# So above 65 are consideredd as ourtliers.

# %% [markdown]
# ##### Boxplot Analysis
# ![image.png](attachment:image.png)
# so the middle blue part is called as Inter quartile range (btwn 25 and 75  ) or we can call it as median(IQR) ,lower part is q1 and upper part is q2.
# and anything
# below the min line(q1) that is q1 - 1.5 x IQR is an outlier.
#              above the max line(q2) that is q2 + 1.5 x IQR is an outlier.
#
#
# So lets check:-

# %%
df[df['Age'] > 65] 
# it looks fine.
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %% [markdown]
# Now lets see if any person's age is not mentioned.

# %%
df['Age'].isnull().sum()
# 177 missing age values
# Out:
# 177

# %%
df['Age'].isnull().sum() / len(df['Age']) * 100 
#almsot 20% missing values
# Out:
# 19.865319865319865

# %% [markdown]
# ## Univariate Analysis on Fare column

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %% [markdown]
# * 25% is below 7 dollar
# * 50% is below 14 dollars or the median is 14 dollars

# %%
'''ax = sns.histplot(data = df['Fare'],bins = 50);
ax.set_xlim(0,300)
'''
df['Fare'].plot(kind = 'hist',bins = 20);
plt.ylim(0,600);
plt.xlim(0,300,50);
# Out:
# C:\Users\Raghavendra s\AppData\Local\Temp\ipykernel_8092\3898335588.py:6: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,300,50);

# %% [markdown]
# So a lot ofpeople are travelling by paying less than 50.
# We can understand more by plotting kdeplot.

# %%
df['Fare'].plot(kind = 'kde');
# its skewed

# %%
df['Fare'].skew()
#highly positively skewed
# Out:
# 4.787316519674893

# %% [markdown]
# Highly skewed data

# %% [markdown]
# Now lets further understand by plotting a boxplot.

# %%
ax = sns.boxplot(data = df['Fare']);

# %% [markdown]
# Clearly ther are a lot of outliers.
# max = 100 ,lets try to analyse with fare above 200 and see whats happening.

# %%
df[df['Fare'] > 250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# Ok So 263  is the sum of tickets of everyone present in the family.(i.e 4 ppl)
# so its group fare and not individual fare.
# Maybe ,later we might need to find fare of individuals.

# %% [markdown]
# ### Univariate Analysis on Categorical columns

# %% [markdown]
# * Frequency distribution.
# * Visualization: Countplot , piechart

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
ax = sns.countplot(data = df,
                   x = df['Survived'],
                  palette = 'husl');
#ax.set_ylim([0,600]);
ax.set_yticks(range(0,600,50));
#or 
'''df['Survived'].value_counts().plot(kind = 'bar');
plt.ylim(0,600);
'''
# Out:
# "df['Survived'].value_counts().plot(kind = 'bar');\nplt.ylim(0,600);\n"

# %% [markdown]
# to find the number of deaths we can use piechart

# %%
counts = df['Survived'].value_counts()
explode = (0.1,0)
plt.pie(counts, labels=['Did not survive', 'Survived'],
        autopct='%0.1f%%',
        shadow=True, 
        startangle=90,
        explode = explode ,
        colors  = sns.color_palette('Set1'));
plt.title('Survival Distribution')
# Out:
# Text(0.5, 1.0, 'Survival Distribution')

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# Most people are travelling in class 3 and then 2 and least is 1.

# %%
counts = df['Pclass'].value_counts()
plt.pie(counts , labels = ['Class 3' , 'Class 2 ', 'Class 1'],
        explode = (0.05 , 0.05 ,0.05) ,
        shadow = True ,
        startangle = 90 ,
       autopct = '%0.1f%%', 
       colors = sns.color_palette('Set1'));

# %% [markdown]
# #### SEx

# %%
df['Sex'].value_counts().plot(kind = 'pie',
                             explode = (0.05,0.01) ,
                             labels = ["Male", "Female"],
                             colors = sns.color_palette('Set1'),
                             autopct = "%0.1f%%",
                             startangle = 90);
plt.title('Gender Comparison',fontsize = 14);

# %% [markdown]
# ### SibSp
# **Parent child ,wife husband details**

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %% [markdown]
# 1 - 209 ,1 person could be husband wife or brother ,sister.
# 2 - 28  ,2 ppl could be kids etc...

# %% [markdown]
# Countplot / barplot to check since its catergorical data.

# %%
ax = sns.countplot(data = df,
                   x = df['SibSp'],
                  palette = 'husl');
#ax.set_ylim([0,600]);
ax.set_yticks(range(0,600,50));

# %%
counts = df['SibSp'].value_counts()
plt.pie(counts , 
        shadow = True ,
        startangle = 90 ,
       autopct = '%0.1f%%', 
       colors = sns.color_palette('Set1'));

# %% [markdown]
# ### Parch
# **Its parent child relationship. But it shouldt exist tho cuz its a relationship after all.**
# * So we can merge both columns and call it as family Size
# * We can also create a columnn for ppl who are alone cuz that makes a diffrence in surivival.

# %% [markdown]
# ### Embarked
# **Its basically from whr ppl got into the ship.**

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# Now Univariate analysis of Mixed columns is left out . I.e is Name ,ticket and Cabin.
# We cant just diretly jump into analysis with these so lets feature engineer first.

# %% [markdown]
# ## Bivariate analysis
# * Done on 2 columns.
# * Understand the relationship.
#
#   1. **Numerical-Numerical**
#
#      a. Use scatterplots (regression plots), histplots, and 2D kdeplots to visualize the relationship.
#      b. Check the correlation coefficient to assess the linear relationship.
#   2. **Numerical-Categorical**
#
#      a. Create visualizations comparing the distribution of numerical data across different categories.
#      b. Utilize barplots, boxplots, kdeplots, and scatterplots for this analysis.
#   3. **Categorical-Categorical**
#
#      a. Generate cross-tabulations or contingency tables showing the distribution of values in one column grouped by values in another column.
#      b. Utilize visualizations such as heatmaps, stacked barplots, and treemaps to represent the relationships.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Survived vs Pclass
# its categorical vs categorical

# %%
pd.crosstab(df['Survived'],df['Pclass'])
# if you need percentage then pd.crosstab(df['Survived'],df['Pclass'], normalize = 'columns') * 100
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# In class 3 maximium people died.
# class 1 surived cuz they are rich.

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'], normalize = 'columns') * 100);

# %% [markdown]
# Survived vs gender

# %%
pd.crosstab(df['Survived'], df['Sex'], normalize = 'columns') * 100
#Most men died ,very sad
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
df['Survived'] = df['Survived'].map({0 : 'Died', 1 : 'Survived'})
sns.heatmap(  pd.crosstab(df['Survived'], df['Sex'], normalize='columns') * 100,
            annot=True);

# %% [markdown]
# Now lets see if location and death has any relationship.

# %%
pd.crosstab(df['Survived'], df['Embarked'], normalize = 'columns') * 100
# Out:
# Embarked          C          Q          S
# Survived
# Died      44.642857  61.038961  66.304348
# Survived  55.357143  38.961039  33.695652

# %% [markdown]
# So from place C 55% ppl survived which is weird because logically place shouldnt make a difference.
# The only 2 explanation is that from C Maximum females got in the ship or they are from 1st class sunce 1st class many people survived due to priority.Lets check.

# %%
pd.crosstab(df['Sex'], df['Embarked'] , normalize = 'columns') * 100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %% [markdown]
# Since gender isnt really making a difference lets check if ticket type(1st class ,2nd class) is makuinf a difference

# %%
pd.crosstab(df['Pclass'], df['Embarked'] , normalize = 'columns') * 100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# Yes 50% ppl from C station are from 1st class hence they survived.
# Also SibSP and Parch we'll convert as single colummn.

# %% [markdown]
# ### Age-Survived
# Its Numerical vs Categorical type

# %%
df[df['Survived'] == 'Died']['Age'].plot(kind = 'kde',label = 'Died')
df[df['Survived'] == 'Survived']['Age'].plot(kind = 'kde',label = 'Survived')
plt.legend()
plt.show()

# %% [markdown]
# Conclusion till now :-

# %% [markdown]
# **Now lets feature engineer.
# Firstly lets engineer Fare column.**

# %%
df[df['Fare'] > 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259  Survived       1                    Ward, Miss. Anna
# 679          680  Survived       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738  Survived       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %% [markdown]
# Main idea is to make sure that we have individual fares.

# %%
# SibSp - Sibling Spouse  
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %% [markdown]
# Lets first deal with families(i.e 8)

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId Survived  Pclass                               Name     Sex  \
# 159          160     Died       3         Sage, Master. Thomas Henry    male
# 180          181     Died       3       Sage, Miss. Constance Gladys  female
# 201          202     Died       3                Sage, Mr. Frederick    male
# 324          325     Died       3           Sage, Mr. George John Jr    male
# 792          793     Died       3            Sage, Miss. Stella Anna  female
# 846          847     Died       3           Sage, Mr. Douglas Bullen    male
# 863          864     Died       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# SibSip- 8 , Parch - 2
# It means toal 11 memebrs but here only 7 are visible ,it means
# * They have seperate tickets or data could be missing.

# %%
df[df['Name'].str.contains("Sage")]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160      Died       3         Sage, Master. Thomas Henry    male
# 180          181      Died       3       Sage, Miss. Constance Gladys  female
# 201          202      Died       3                Sage, Mr. Frederick    male
# 324          325      Died       3           Sage, Mr. George John Jr    male
# 641          642  Survived       1               Sagesser, Mlle. Emma  female
# 792          793      Died       3            Sage, Miss. Stella Anna  female
# 846          847      Died       3           Sage, Mr. Douglas Bullen    male
# 863          864      Died       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %% [markdown]
# **Sagesser, Mlle. Emma** Is someone else ,it means Data is missing.
# ok so the rest family details is in test data set.

# %%
df1 = pd.read_csv("test.csv")

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# Now lets joij both DataSet

# %%
 df = pd.concat([df,df1])

# %% [markdown]
# NOw lets see if we can find the rest family members.

# %%
df[df['Ticket'] == 'CA. 2343']
# yes toal 11 are present.
# Out:
#      PassengerId Survived  Pclass                               Name     Sex  \
# 159          160     Died       3         Sage, Master. Thomas Henry    male
# 180          181     Died       3       Sage, Miss. Constance Gladys  female
# 201          202     Died       3                Sage, Mr. Frederick    male
# 324          325     Died       3           Sage, Mr. George John Jr    male
# 792          793     Died       3            Sage, Miss. Stella Anna  female
# 846          847     Died       3           Sage, Mr. Douglas Bullen    male
# 863          864     Died       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080      NaN       3                    Sage, Miss. Ada  female
# 342         1234      NaN       3              Sage, Mr. John George    male
# 360         1252      NaN       3        Sage, Master. William Henry    male
# 365         1257      NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df['Individual Fare'] = df['Fare'] / (df['SibSp'] +  df['Parch'] + 1)

# %%
ax = sns.boxplot(data = df ,
                 y = df['Individual Fare'])

# %% [markdown]
# Still someone has paid 500 dolllars ,lets check is its legit

# %%
df[['Individual Fare', 'Fare']].describe()
# So someone is actually travelling at 512 dollars.
# Out:
#        Individual Fare         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Died       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Died       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Now Lets fix SibSp and Parch issue

# %%
df['Family Size'] = df['SibSp'] + df['Parch']+ 1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Individual Fare  \
# 0      0         A/5 21171   7.2500   NaN        S          3.62500
# 1      0          PC 17599  71.2833   C85        C         35.64165
# 2      0  STON/O2. 3101282   7.9250   NaN        S          7.92500
# ...

# %% [markdown]
# Now lets add another collum in which we know the family type.

# %%
def FamilyTypeFx(num): 
    if num == 1 :
        return 'Alone'
    elif num>1 and num < 5 : 
        return 'medium'
    else:
        return 'large'

# %%
df['Family Type'] = df['Family Size'].apply(FamilyTypeFx)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1      Died       3
# 1              2  Survived       1
# 2              3  Survived       3
# 3              4  Survived       1
# 4              5      Died       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['Family Type'], normalize = 'columns') * 100
# Out:
# Family Type      Alone      large     medium
# Survived
# Died         69.646182  83.870968  42.123288
# Survived     30.353818  16.129032  57.876712
